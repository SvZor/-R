# %%
print ("привет")
# Out:
# привет

# %% [markdown]
# Запомните эти горячие клавиши для работы с подсказками в VS Code:
#
# Действие	Клавиши
# Принять подсказку	Tab или Enter
# Закрыть подсказку (не принимая)	Esc
# Вызвать подсказки вручную	Ctrl+Пробел
